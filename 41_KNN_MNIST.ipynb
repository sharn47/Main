# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
scalar.fit(digits.data)
new=scalar.transform(digits.data)

# %%
np.shape(new)
# Out:
# (1797, 64)

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split( new,digits.target, test_size = 0.25 ,random_state= 42)

# %%
sse = []
k_rng = range(1,30)
for k in k_rng:
    knn = KNeighborsClassifier(n_neighbors=6)
    knn.fit(x_train,y_train)
    sse.append(1-knn.score(x_test,y_test))

# %%
import matplotlib.pyplot as plt
plt.plot(k_rng,sse)
