# %%
from google.colab import drive# this is to import files from google drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AHn6lMmi7OgndoH4QByESISqVEyv3yGX9FOWcv0eSFQY-__kL8hAuo
# Mounted at /content/gdrive

# %%
root_dir = "/content/gdrive/My Drive/Datas/"

# %%
import pandas as pd
train=pd.read_csv(root_dir+"train.csv")# root directory is the drive
test=pd.read_csv(root_dir+"test.csv")# root directory is the drive

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.288585          -0.020294  ...        1  STANDING
# 1           0.278419          -0.016411  ...        1  STANDING
# 2           0.279653          -0.019467  ...        1  STANDING
# 3           0.279174          -0.026201  ...        1  STANDING
# 4           0.276629          -0.016570  ...        1  STANDING
#
# [5 rows x 563 columns]

# %%
train.drop(["Activity","subject"],axis=1)
# Out:
#       tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# 0              0.288585  ...             -0.058627
# 1              0.278419  ...             -0.054317
# 2              0.279653  ...             -0.049118
# 3              0.279174  ...             -0.047663
# 4              0.276629  ...             -0.043892
# ...                 ...  ...                   ...
# 7347           0.299665  ...              0.049819
# 7348           0.273853  ...              0.050053
# 7349           0.273387  ...              0.040811
# 7350           0.289654  ...              0.025339
# 7351           0.351503  ...              0.036695
#
# [7352 rows x 561 columns]

# %%
test.drop(["Activity","subject"],axis=1)
# Out:
#       tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# 0              0.257178  ...             -0.057978
# 1              0.286027  ...             -0.083898
# 2              0.275485  ...             -0.079346
# 3              0.270298  ...             -0.077108
# 4              0.274833  ...             -0.073857
# ...                 ...  ...                   ...
# 2942           0.310155  ...              0.184784
# 2943           0.363385  ...              0.182412
# 2944           0.349966  ...              0.181184
# 2945           0.237594  ...              0.187563
# 2946           0.153627  ...              0.188103
#
# [2947 rows x 561 columns]

# %%
df=pd.DataFrame(train.drop(["Activity","subject"],axis=1))

# %%
test1=pd.DataFrame(test.drop(["Activity","subject"],axis=1))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)

# Apply transform to both the training set and the test set.
train_1= scaler.transform(df)

# %%
test_1= scaler.transform(test1)

# %%
from sklearn.decomposition import PCA
pca = PCA(.95)
pca.fit(df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.n_components_
# Out:
# 67

# %%
train_1 = pca.transform(df)

# %%
test_1= pca.transform(test1)

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.288585          -0.020294  ...        1  STANDING
# 1           0.278419          -0.016411  ...        1  STANDING
# 2           0.279653          -0.019467  ...        1  STANDING
# 3           0.279174          -0.026201  ...        1  STANDING
# 4           0.276629          -0.016570  ...        1  STANDING
#
# [5 rows x 563 columns]

# %%
y= train['Activity'].values

# %%
y_test= test['Activity'].values

# %%
print(y)
# Out:
# ['STANDING' 'STANDING' 'STANDING' ... 'WALKING_UPSTAIRS'
#  'WALKING_UPSTAIRS' 'WALKING_UPSTAIRS']

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()

# %%
encoder.fit(y)
Y_train = encoder.transform(y)

# %%
test_2= encoder.transform(y_test)

# %%
test_2
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %%
Y_train
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %%
import numpy as np
from sklearn import svm

# %%
model = svm.SVC(kernel='linear',C=2**-5)
model.fit(train_1,Y_train)
# Out:
# SVC(C=0.03125, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
np.shape(train_1)
# Out:
# (7352, 67)

# %%
np.shape(test_1)
# Out:
# (2947, 67)

# %%
np.shape(Y_train)
# Out:
# (7352,)

# %%
np.shape(test_2)
# Out:
# (7352,)

# %%
model.score(test_1,test_2)
# Out:
# 0.9395995928062436

# %%
score = metrics.accuracy_score(test_lbl, y_pre)
print("Accuracy score: {}".format(score))

# %%
model = svm.SVC(kernel='rbf',gamma=2**-5,C=1)
model.fit(train_1,Y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.03125, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(test_1,test_2)
# Out:
# 0.9443501866304717

# %%
model = svm.SVC(kernel='poly',degree=4, gamma=2**-5,C=1)
model.fit(train_1,Y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=4, gamma=0.03125, kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(test_1,test_2)
# Out:
# 0.9226331862911435
